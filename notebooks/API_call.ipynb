# %%
import requests
import os
import re
import emoji
import pandas as pd
from collections import Counter, defaultdict
import string
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')

# %%
def text_cleaner(input_text):
    # Remove URLs
    text_without_urls = re.sub(r'http\S+', '', input_text)
    
    # Remove punctuation, including special characters like '›'
    clean_text = ''.join([char if char not in string.punctuation + '›' else ' ' for char in text_without_urls])
    
    # Convert text to lowercase and split into words
    words = clean_text.lower().split()
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)  # Join the words back into a string

# %%
def fetch_arxiv_data(search_query, max_results=10, start_date=None, end_date=None, primary_category=None, categories=None):
    # Define the API endpoint URL for searching articles
    api_url = "http://export.arxiv.org/api/query"

    # Define additional parameters like start and max_results
    params = {
        "search_query": search_query,
        "start": 0,  # Start index of results
        "max_results": max_results,  # Maximum number of results to retrieve
    }

    # Add start and end date parameters if provided
    if start_date is not None:
        params["start_date"] = start_date
    if end_date is not None:
        params["end_date"] = end_date

    # Add primary category and categories parameters if provided
    if primary_category is not None:
        params["cat"] = primary_category
    if categories is not None:
        params["categories"] = categories

    # Send an HTTP GET request to the arXiv API
    response = requests.get(api_url, params=params)

    # Check if the request was successful (HTTP status code 200)
    if response.status_code == 200:
        # Parse the response content using BeautifulSoup
        soup = BeautifulSoup(response.content, "xml")

        # Create a list to store article information
        articles = []

        # Extract article information from the parsed content
        entries = soup.find_all("entry")
        for entry in entries:
            title = entry.find("title").text
            paper_id = entry.find("id").text
            published = entry.find("published").text
            updated = entry.find("updated").text
            summary = entry.find("summary").text
            author = [author.text for author in entry.find_all("author")]
            comments = entry.find("arxiv:comment").text if entry.find("arxiv:comment") else ""
            journal_ref = entry.find("arxiv:journal_ref").text if entry.find("arxiv:journal_ref") else ""
            link = entry.find("link")["href"] if entry.find("link") else ""
            primary_category = entry.find("arxiv:primary_category")["term"] if entry.find("arxiv:primary_category") else ""
            categories = [cat["term"] for cat in entry.find_all("category")]
            doi = entry.find("arxiv:doi").text if entry.find("arxiv:doi") else ""
            license = entry.find("arxiv:license")["type"] if entry.find("arxiv:license") else ""
            affiliation = [aff.text for aff in entry.find_all("arxiv:affiliation")]


            # Append article information to the list
            articles.append({
                "Title": title,
                "ID": paper_id,
                "Published": published,
                "Updated": updated,
                "Summary": summary,
                "Author": author,
                "Comments": comments,
                "Journal_Ref": journal_ref,
                "Link": link,
                "Primary_Category": primary_category,
                "Categories": categories,
                "DOI": doi,
                "License": license,
                "Affiliation": affiliation,
            })

        # Create a DataFrame from the list of articles
        df = pd.DataFrame(articles)

        # Return the DataFrame
        return df

    else:
        print("Failed to retrieve data from arXiv API")
        return None

# %%
def extract_text_from_link(link):
    try:
        # Send an HTTP GET request to the link without verifying SSL certificates
        response = requests.get(link, verify=False)
        if response.status_code == 200:
            # Parse the HTML content using BeautifulSoup
            soup = BeautifulSoup(response.content, "html.parser")
            # Extract text from the HTML content
            text = soup.get_text()
            return text
        else:
            print(f"Failed to retrieve content from {link}")
            return None
    except Exception as e:
        print(f"Error occurred while fetching content from {link}: {str(e)}")
        return None

# %%
def process_links(df):
    # Create a new column for cleaned and tokenized text
    df['Cleaned_Text'] = ''
    
    # Iterate through each row
    for index, row in df.iterrows():
        # Extract link from the "Link" column
        link = row['Link']
        # Extract text content from the link
        text = extract_text_from_link(link)
        if text:
            # Clean and tokenize the text
            cleaned_text = text_cleaner(text)
            # Update the corresponding row in the DataFrame
            df.at[index, 'Cleaned_Text'] = cleaned_text
        else:
            # If unable to fetch content, leave the "Cleaned_Text" column empty for that row
            df.at[index, 'Cleaned_Text'] = ''
        
        # Split the cleaned text into words
        cleaned_text_words = cleaned_text.split()
        # Join the words with commas
        cleaned_text_comma_separated = ", ".join(cleaned_text_words)
    
    return df

# %%
# %%time
# Fetch data from arXiv and store it in a DataFrame
df = fetch_arxiv_data(search_query="quantum physics", max_results=10, start_date="2023-01-01", end_date="2023-12-31", primary_category="quant-ph", categories=["quant-ph", "cond-mat"])

# Process links in the DataFrame to clean and tokenize text
df_with_cleaned_text = process_links(df)
# Out:
# CPU times: total: 2.02 s
# Wall time: 9.67 s

# %%
df_with_cleaned_text
# Out:
#                                                Title  \
# 0  Nonlinear Dynamics In Quantum Physics -- Quant...
# 1                            Quantum spherical model
# 2  Can classical physics agree with quantum physi...
# 3                 The Physics of Quantum Information
# 4  Topologization of electron liquids with Chern-...
# 5  Operational Quantum Mechanics, Quantum Axiomat...
# 6  Universal Uncertainty Principle in Different Q...
# 7  Quantum Computers and Quantum Computer Languag...
# 8  Probabilistic foundations of quantum mechanics...
# 9        From quantum graphs to quantum random walks
#
#                                         ID             Published  \
# 0  http://arxiv.org/abs/quant-ph/0302169v1  2003-02-21T20:20:47Z
# 1         http://arxiv.org/abs/1212.4177v1  2012-12-17T22:06:56Z
# 2        http://arxiv.org/abs/1504.03207v1  2015-04-13T15:04:26Z
# 3        http://arxiv.org/abs/2208.08064v1  2022-08-17T04:35:36Z
# 4  http://arxiv.org/abs/cond-mat/0601285v1  2006-01-13T09:06:10Z
# 5         http://arxiv.org/abs/0811.2516v1  2008-11-15T18:37:02Z
# 6        http://arxiv.org/abs/1807.11019v1  2018-07-29T07:50:32Z
# 7  http://arxiv.org/abs/quant-ph/0201082v1  2002-01-18T15:08:05Z
# 8  http://arxiv.org/abs/quant-ph/0309066v1  2003-09-08T09:37:27Z
# 9  http://arxiv.org/abs/quant-ph/0504224v1  2005-04-29T09:41:00Z
#
#                 Updated                                            Summary  \
# 0  2003-02-21T20:20:47Z    We discuss the recently proposed quantum act...
# 1  2012-12-17T22:06:56Z    We define a "quantum spherical model", a qua...
# 2  2015-04-13T15:04:26Z    Classical physics fails where quantum physic...
# 3  2022-08-17T04:35:36Z    Rapid ongoing progress in quantum informatio...
# 4  2006-01-13T09:06:10Z    We discuss a nexus among quantum topology, q...
# 5  2008-11-15T18:37:02Z    The role of operational quantum mechanics, q...
# 6  2018-07-29T07:50:32Z    This paper deduces universal uncertainty pri...
# 7  2002-01-18T15:08:05Z    We show a representation of Quantum Computer...
# 8  2003-09-08T09:37:27Z    We discuss foundation of quantum mechanics (...
# 9  2005-04-29T09:41:00Z    We give a short overview over recent develop...
#
#                                  Author  \
# 0                       [\nH. Kröger\n]
# 1                       [\nI. Lyberg\n]
# 2                [\nMichele Marrocco\n]
# 3                   [\nJohn Preskill\n]
# 4                   [\nZhenghan Wang\n]
# 5                  [\nDiederik Aerts\n]
# 6  [\nC. Huang\n, \nYong-Chang Huang\n]
# 7                   [\nStephen Blaha\n]
# 8               [\nAndrei Khrennikov\n]
# 9                   [\nGregor Tanner\n]
#
#                                             Comments  \
# 0  inv. talk, 10th Int. Conf. Comput. and Appl. M...
# 1
# 2                                            9 pages
# 3  23 pages. Overview talk at the 28th Solvay Con...
# 4
# 5                                            6 pages
# 6                                           15 pages
# 7                                           32 pages
# 8  Contextual probabilistic viewpoint to quantum ...
# 9                                14 pages, 6 figures
#
#                                          Journal_Ref  \
# 0
# 1
# 2
# 3
# 4
# 5  In D. Greenberger, K. Hentschel and F. Wienert...
# 6
# 7
# 8
# 9
#
#                                           Link   Primary_Category  \
# 0      http://arxiv.org/abs/quant-ph/0302169v1           quant-ph
# 1             http://arxiv.org/abs/1212.4177v1            math-ph
# 2            http://arxiv.org/abs/1504.03207v1   physics.class-ph
# 3            http://arxiv.org/abs/2208.08064v1           quant-ph
# 4      http://arxiv.org/abs/cond-mat/0601285v1  cond-mat.mes-hall
# 5  http://dx.doi.org/10.1007/978-3-540-70626-7    physics.hist-ph
# 6            http://arxiv.org/abs/1807.11019v1           quant-ph
# 7      http://arxiv.org/abs/quant-ph/0201082v1           quant-ph
# 8          http://dx.doi.org/10.1117/12.517850           quant-ph
# 9    http://dx.doi.org/10.1007/1-4020-3949-2_6           quant-ph
#
#                               Categories                        DOI License  \
# 0                             [quant-ph]
# 1                     [math-ph, math.MP]
# 2           [physics.class-ph, quant-ph]
# 3    [quant-ph, cond-mat.str-el, hep-th]
# 4  [cond-mat.mes-hall, math-ph, math.MP]
# 5            [physics.hist-ph, quant-ph]  10.1007/978-3-540-70626-7
# 6                             [quant-ph]
# 7                      [quant-ph, cs.PL]
# 8                             [quant-ph]          10.1117/12.517850
# 9                             [quant-ph]    10.1007/1-4020-3949-2_6
#
#   Affiliation                                       Cleaned_Text
# 0          []  quant ph 0302169v1 nonlinear dynamics quantum ...
# 1          []  1212 4177v1 quantum spherical model skip main ...
# 2          []  1504 03207v1 classical physics agree quantum p...
# 3          []  2208 08064v1 physics quantum information skip ...
# 4          []  cond mat 0601285v1 topologization electron liq...
# 5          []  compendium quantum physics concepts experiment...
# 6          []  1807 11019v1 universal uncertainty principle d...
# 7          []  quant ph 0201082v1 quantum computers quantum c...
# 8          []  probabilistic foundations quantum mechanics qu...
# 9          []  quantum graphs quantum random walks springerli...

# %%
# Iterate over the first 5 rows
for index, row in df_with_cleaned_text.head().iterrows():
    print(f"Row {index + 1}:")
    print("Summary:", row['Summary'])
    print("Cleaned Text:\n", row['Cleaned_Text'])
    print()  # Print a blank line for better readability
# Out:
# Row 1:
# Summary:   We discuss the recently proposed quantum action - its interpretation, its
# motivation, its mathematical properties and its use in physics: quantum
# mechanical tunneling, quantum instantons and quantum chaos.
#
# Cleaned Text:
#  quant ph 0302169v1 nonlinear dynamics quantum physics quantum chaos quantum instantons skip main content gratefully acknowledge support simons foundation member institutions contributors donate quant ph arxiv quant ph 0302169v1 help advanced search fields title author abstract comments journal reference acm classification msc classification report number arxiv identifier doi orcid arxiv author id help pages full text search open search go open navigation menu quick links login help pages quantum physics arxiv quant ph 0302169v1 quant ph submitted 21 feb 2003 title nonlinear dynamics quantum physics quantum chaos quantum instantons authors h kröger download pdf paper titled nonlinear dynamics quantum physics quantum chaos quantum instantons h kr oger download pdf abstract discuss recently proposed quantum action interpretation motivation mathematical properties use physics quantum mechanical tunneling quantum instantons quantum chaos comments inv talk 10th int conf comput appl math leuven belgium 2002 subjects quantum physics quant ph cite arxiv quant ph 0302169 arxiv quant ph 0302169v1 version focus learn arxiv issued doi via datacite submission history helmut kroger view email v1 fri 21 feb 2003 20 20 47 utc 121 kb full text links access paper download pdf paper titled nonlinear dynamics quantum physics quantum chaos quantum instantons h kr ogerdownload pdfother formats view license current browse context quant ph prev next new recent 0302 references citations inspire hep nasa adsgoogle scholar semantic scholar export bibtex citation loading bibtex formatted citation × loading data provided bookmark bibliographic tools bibliographic citation tools bibliographic explorer toggle bibliographic explorer explorer litmaps toggle litmaps litmaps scite ai toggle scite smart citations smart citations code data media code data media associated article links code toggle catalyzex code finder papers catalyzex dagshub toggle dagshub dagshub links code toggle papers code papers code sciencecast toggle sciencecast sciencecast demos demos replicate toggle replicate replicate spaces toggle hugging face spaces spaces spaces toggle txyz ai txyz ai related papers recommenders search tools link influence flower influence flower influence flowers connected papers toggle connected papers connected papers core recommender toggle core recommender core author venue institution topic arxivlabs arxivlabs experimental projects community collaborators arxivlabs framework allows collaborators develop share new arxiv features directly website individuals organizations work arxivlabs embraced accepted values openness community excellence user data privacy arxiv committed values works partners adhere idea project add value arxiv community learn arxivlabs authors paper endorsers disable mathjax mathjax help contact arxivclick contact arxiv contact subscribe arxiv mailingsclick subscribe subscribe copyright privacy policy web accessibility assistance arxiv operational status get status notifications via email slack
#
# Row 2:
# Summary:   We define a "quantum spherical model", a quantum lattice model.
#
# Cleaned Text:
#  1212 4177v1 quantum spherical model skip main content gratefully acknowledge support simons foundation member institutions contributors donate math ph arxiv 1212 4177v1 help advanced search fields title author abstract comments journal reference acm classification msc classification report number arxiv identifier doi orcid arxiv author id help pages full text search open search go open navigation menu quick links login help pages mathematical physics arxiv 1212 4177v1 math ph submitted 17 dec 2012 title quantum spherical model authors lyberg download pdf paper titled quantum spherical model lyberg download pdf abstract define quantum spherical model quantum lattice model subjects mathematical physics math ph cite arxiv 1212 4177 math ph arxiv 1212 4177v1 math ph version focus learn arxiv issued doi via datacite submission history ivar lyberg view email v1 mon 17 dec 2012 22 06 56 utc 4 kb full text links access paper download pdf paper titled quantum spherical model lybergdownload pdfother formats view license current browse context math ph prev next new recent 1212 change browse math math mp references citations nasa adsgoogle scholar semantic scholar export bibtex citation loading bibtex formatted citation × loading data provided bookmark bibliographic tools bibliographic citation tools bibliographic explorer toggle bibliographic explorer explorer litmaps toggle litmaps litmaps scite ai toggle scite smart citations smart citations code data media code data media associated article links code toggle catalyzex code finder papers catalyzex dagshub toggle dagshub dagshub links code toggle papers code papers code sciencecast toggle sciencecast sciencecast demos demos replicate toggle replicate replicate spaces toggle hugging face spaces spaces spaces toggle txyz ai txyz ai related papers recommenders search tools link influence flower influence flower influence flowers connected papers toggle connected papers connected papers core recommender toggle core recommender core author venue institution topic arxivlabs arxivlabs experimental projects community collaborators arxivlabs framework allows collaborators develop share new arxiv features directly website individuals organizations work arxivlabs embraced accepted values openness community excellence user data privacy arxiv committed values works partners adhere idea project add value arxiv community learn arxivlabs authors paper endorsers disable mathjax mathjax help contact arxivclick contact arxiv contact subscribe arxiv mailingsclick subscribe subscribe copyright privacy policy web accessibility assistance arxiv operational status get status notifications via email slack
#
# Row 3:
# Summary:   Classical physics fails where quantum physics prevails. This common
# understanding applies to quantum phenomena that are acknowledged to be beyond
# the reach of classical physics. Here, we make an attempt at weakening this
# solid belief that classical physics is unfit to explain the quantum world. The
# trial run is the quantization of the free radiation field that will be
# addressed by following a strategy that is free from operators or
# quantum-mechanical concepts
#
# Cleaned Text:
#  1504 03207v1 classical physics agree quantum physics quantum phenomena skip main content gratefully acknowledge support simons foundation member institutions contributors donate physics arxiv 1504 03207v1 help advanced search fields title author abstract comments journal reference acm classification msc classification report number arxiv identifier doi orcid arxiv author id help pages full text search open search go open navigation menu quick links login help pages physics classical physics arxiv 1504 03207v1 physics submitted 13 apr 2015 title classical physics agree quantum physics quantum phenomena authors michele marrocco download pdf paper titled classical physics agree quantum physics quantum phenomena michele marrocco download pdf abstract classical physics fails quantum physics prevails common understanding applies quantum phenomena acknowledged beyond reach classical physics make attempt weakening solid belief classical physics unfit explain quantum world trial run quantization free radiation field addressed following strategy free operators quantum mechanical concepts comments 9 pages subjects classical physics physics class ph quantum physics quant ph cite arxiv 1504 03207 physics class ph arxiv 1504 03207v1 physics class ph version focus learn arxiv issued doi via datacite submission history michele marrocco view email v1 mon 13 apr 2015 15 04 26 utc 216 kb full text links access paper download pdf paper titled classical physics agree quantum physics quantum phenomena michele marroccodownload pdf view license current browse context physics class ph prev next new recent 1504 change browse physics quant ph references citations inspire hep nasa adsgoogle scholar semantic scholar export bibtex citation loading bibtex formatted citation × loading data provided bookmark bibliographic tools bibliographic citation tools bibliographic explorer toggle bibliographic explorer explorer litmaps toggle litmaps litmaps scite ai toggle scite smart citations smart citations code data media code data media associated article links code toggle catalyzex code finder papers catalyzex dagshub toggle dagshub dagshub links code toggle papers code papers code sciencecast toggle sciencecast sciencecast demos demos replicate toggle replicate replicate spaces toggle hugging face spaces spaces spaces toggle txyz ai txyz ai related papers recommenders search tools link influence flower influence flower influence flowers connected papers toggle connected papers connected papers core recommender toggle core recommender core author venue institution topic arxivlabs arxivlabs experimental projects community collaborators arxivlabs framework allows collaborators develop share new arxiv features directly website individuals organizations work arxivlabs embraced accepted values openness community excellence user data privacy arxiv committed values works partners adhere idea project add value arxiv community learn arxivlabs authors paper endorsers disable mathjax mathjax help contact arxivclick contact arxiv contact subscribe arxiv mailingsclick subscribe subscribe copyright privacy policy web accessibility assistance arxiv operational status get status notifications via email slack
#
# Row 4:
# Summary:   Rapid ongoing progress in quantum information science makes this an apt time
# for a Solvay Conference focused on The Physics of Quantum Information. Here I
# review four intertwined themes encompassed by this topic: Quantum computer
# science, quantum hardware, quantum matter, and quantum gravity. Though the time
# scale for broad practical impact of quantum computation is still uncertain, in
# the near future we can expect noteworthy progress toward scalable
# fault-tolerant quantum computing, and discoveries enabled by programmable
# quantum simulators. In the longer term, controlling highly complex quantum
# matter will open the door to profound scientific advances and powerful new
# technologies.
#
# Cleaned Text:
#  2208 08064v1 physics quantum information skip main content gratefully acknowledge support simons foundation member institutions contributors donate quant ph arxiv 2208 08064v1 help advanced search fields title author abstract comments journal reference acm classification msc classification report number arxiv identifier doi orcid arxiv author id help pages full text search open search go open navigation menu quick links login help pages quantum physics arxiv 2208 08064v1 quant ph submitted 17 aug 2022 title physics quantum information authors john preskill download pdf paper titled physics quantum information john preskill download pdf abstract rapid ongoing progress quantum information science makes apt time solvay conference focused physics quantum information review four intertwined themes encompassed topic quantum computer science quantum hardware quantum matter quantum gravity though time scale broad practical impact quantum computation still uncertain near future expect noteworthy progress toward scalable fault tolerant quantum computing discoveries enabled programmable quantum simulators longer term controlling highly complex quantum matter open door profound scientific advances powerful new technologies comments 23 pages overview talk 28th solvay conference physics physics quantum information 19 21 may 2022 subjects quantum physics quant ph strongly correlated electrons cond mat str el high energy physics theory hep th cite arxiv 2208 08064 quant ph arxiv 2208 08064v1 quant ph version focus learn arxiv issued doi via datacite submission history john preskill view email v1 wed 17 aug 2022 04 35 36 utc 60 kb full text links access paper download pdf paper titled physics quantum information john preskilldownload pdfother formats view license current browse context quant ph prev next new recent 2208 change browse cond mat cond mat str el hep th references citations inspire hep nasa adsgoogle scholar semantic scholar 1 blog link export bibtex citation loading bibtex formatted citation × loading data provided bookmark bibliographic tools bibliographic citation tools bibliographic explorer toggle bibliographic explorer explorer litmaps toggle litmaps litmaps scite ai toggle scite smart citations smart citations code data media code data media associated article links code toggle catalyzex code finder papers catalyzex dagshub toggle dagshub dagshub links code toggle papers code papers code sciencecast toggle sciencecast sciencecast demos demos replicate toggle replicate replicate spaces toggle hugging face spaces spaces spaces toggle txyz ai txyz ai related papers recommenders search tools link influence flower influence flower influence flowers connected papers toggle connected papers connected papers core recommender toggle core recommender core author venue institution topic arxivlabs arxivlabs experimental projects community collaborators arxivlabs framework allows collaborators develop share new arxiv features directly website individuals organizations work arxivlabs embraced accepted values openness community excellence user data privacy arxiv committed values works partners adhere idea project add value arxiv community learn arxivlabs authors paper endorsers disable mathjax mathjax help contact arxivclick contact arxiv contact subscribe arxiv mailingsclick subscribe subscribe copyright privacy policy web accessibility assistance arxiv operational status get status notifications via email slack
#
# Row 5:
# Summary:   We discuss a nexus among quantum topology, quantum physics and quantum
# computing.
#
# Cleaned Text:
#  cond mat 0601285v1 topologization electron liquids chern simons theory quantum computation skip main content gratefully acknowledge support simons foundation member institutions contributors donate cond mat arxiv cond mat 0601285v1 help advanced search fields title author abstract comments journal reference acm classification msc classification report number arxiv identifier doi orcid arxiv author id help pages full text search open search go open navigation menu quick links login help pages condensed matter mesoscale nanoscale physics arxiv cond mat 0601285v1 cond mat submitted 13 jan 2006 title topologization electron liquids chern simons theory quantum computation authors zhenghan wang download pdf paper titled topologization electron liquids chern simons theory quantum computation zhenghan wang download pdf abstract discuss nexus among quantum topology quantum physics quantum computing subjects mesoscale nanoscale physics cond mat mes hall mathematical physics math ph cite arxiv cond mat 0601285 cond mat mes hall arxiv cond mat 0601285v1 cond mat mes hall version focus learn arxiv issued doi via datacite submission history zhenghan wang view email v1 fri 13 jan 2006 09 06 10 utc 82 kb full text links access paper download pdf paper titled topologization electron liquids chern simons theory quantum computation zhenghan wangdownload pdfother formats view license current browse context cond mat prev next new recent 0601 references citations nasa adsgoogle scholar semantic scholar export bibtex citation loading bibtex formatted citation × loading data provided bookmark bibliographic tools bibliographic citation tools bibliographic explorer toggle bibliographic explorer explorer litmaps toggle litmaps litmaps scite ai toggle scite smart citations smart citations code data media code data media associated article links code toggle catalyzex code finder papers catalyzex dagshub toggle dagshub dagshub links code toggle papers code papers code sciencecast toggle sciencecast sciencecast demos demos replicate toggle replicate replicate spaces toggle hugging face spaces spaces spaces toggle txyz ai txyz ai related papers recommenders search tools link influence flower influence flower influence flowers connected papers toggle connected papers connected papers core recommender toggle core recommender core iarxiv recommender toggle iarxiv recommender iarxiv author venue institution topic arxivlabs arxivlabs experimental projects community collaborators arxivlabs framework allows collaborators develop share new arxiv features directly website individuals organizations work arxivlabs embraced accepted values openness community excellence user data privacy arxiv committed values works partners adhere idea project add value arxiv community learn arxivlabs authors paper endorsers disable mathjax mathjax help contact arxivclick contact arxiv contact subscribe arxiv mailingsclick subscribe subscribe copyright privacy policy web accessibility assistance arxiv operational status get status notifications via email slack

# %%
def get_most_common_words(df):
    most_common_words = []
    
    # Iterate over each row
    for index, row in df.iterrows():
        # Split the cleaned text into words
        cleaned_text_words = row['Cleaned_Text'].split()
        
        # Count the occurrences of each word
        word_counts = Counter(cleaned_text_words)
        
        # Get the 5 most common words
        top_words = word_counts.most_common(5)
        
        # Append the most common words to the list
        most_common_words.append((index, top_words))
    
    return most_common_words

# %%
# Example usage
most_common_words = get_most_common_words(df_with_cleaned_text)

# Print the 5 most common words for each row
for index, top_words in most_common_words:
    print(f"Row {index + 1}:")
    for word, count in top_words:
        print(f"{word}: {count}")
    print()  # Print a blank line for better readability
# Out:
# Row 1:
# quantum: 18
# arxiv: 13
# toggle: 12
# quant: 9
# ph: 9
#
# Row 2:
# arxiv: 13
# toggle: 12
# math: 8
# code: 7
# papers: 7
#
# Row 3:
# physics: 23
# quantum: 13
# arxiv: 13
# toggle: 12
# classical: 9
#
# Row 4:
# quantum: 17
# arxiv: 13
# toggle: 12
# physics: 10
# information: 7
#
# Row 5:
# arxiv: 13
# toggle: 13
# cond: 11
# mat: 11
# quantum: 7
#
# Row 6:
# pages: 21
# quantum: 19
# physics: 19
# book: 17
# history: 15
#
# Row 7:
# quantum: 16
# arxiv: 13
# toggle: 12
# uncertainty: 10
# principle: 9
#
# Row 8:
# quantum: 25
# arxiv: 13
# toggle: 12
# language: 10
# quant: 9
#
# Row 9:
# journal: 28
# quantum: 24
# spie: 24
# proceedings: 14
# sign: 13
#
# Row 10:
# google: 39
# scholar: 38
# ads: 29
# phys: 26
# crossref: 26

# %%
def process_pdf_links(df):
    if df.empty:
        print("The DataFrame is empty. No links to process.")
        return df
    
    # Iterate through each row
    for index, row in df.iterrows():
        # Extract link from the "ID" column
        link = row['ID']  # Update this if the PDF link is stored in a different column
        print(f"Processing link: {link}")  # Debugging log
        # Download PDF content from the link
        pdf_io = download_pdf_from_link(link)
        if pdf_io:
            # Extract text content from the PDF
            text = extract_text_from_pdf(pdf_io)
            print(f"Extracted text length: {len(text)}")  # Debugging log
            # Update the corresponding row in the DataFrame with the extracted text
            df.at[index, 'PDF_Text'] = text
        else:
            print(f"Failed to process link: {link}")
    return df

# Fetch data from arXiv and store it in a DataFrame
df = fetch_arxiv_data(search_query="quantum physics", max_results=10, start_date="2023-01-01", end_date="2023-12-31", primary_category="quant-ph", categories=["quant-ph", "cond-mat"])

# Process links in the DataFrame to download PDFs and extract their text
df_with_pdf_text = process_pdf_links(df)
# Out:
# Processing link: http://arxiv.org/abs/quant-ph/0302169v1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 27
#      24 df = fetch_arxiv_data(search_query="quantum physics", max_results=10, start_date="2023-01-01", end_date="2023-12-31", primary_category="quant-ph", categories=["quant-ph", "cond-mat"])
#      26 # Process links in the DataFrame to download PDFs and extract their text
# ---> 27 df_with_pdf_text = process_pdf_links(df)
#
# Cell In[13], line 12, in process_pdf_links(df)
#      10 print(f"Processing link: {link}")  # Debugging log
#      11 # Download PDF content from the link
# ---> 12 pdf_io = download_pdf_from_link(link)
#      13 if pdf_io:
#      14     # Extract text content from the PDF
#      15     text = extract_text_from_pdf(pdf_io)
#
# NameError: name 'download_pdf_from_link' is not defined

# %%
https://arxiv.org/abs/quant-ph/0302169v1

# %%
https://arxiv.org/pdf/quant-ph/0302169v1.pdf

# %%
import requests
from bs4 import BeautifulSoup
from PyPDF2 import PdfReader
import io
import pandas as pd

def fetch_arxiv_data(search_query, max_results=10, start_date=None, end_date=None, primary_category=None, categories=None):
    api_url = "http://export.arxiv.org/api/query"
    params = {
        "search_query": search_query,
        "start": 0,
        "max_results": max_results,
    }
    if start_date:
        params["start_date"] = start_date
    if end_date:
        params["end_date"] = end_date
    if primary_category:
        params["cat"] = primary_category
    if categories:
        params["categories"] = categories

    response = requests.get(api_url, params=params)
    if response.status_code == 200:
        feed = BeautifulSoup(response.content, features="html.parser")
        entries = feed.find_all('entry')
        articles = []

        for entry in entries:
            article = {}
            article['Title'] = entry.title.text
            article['Authors'] = [author.find('name').text for author in entry.find_all('author')]
            article['Published'] = entry.published.text
            article['Updated'] = entry.updated.text
            article['Summary'] = entry.summary.text.strip()
            article['ID'] = entry.id.text
            articles.append(article)

        df = pd.DataFrame(articles)
        return df
    else:
        print("Failed to retrieve data from arXiv API")
        return None

def download_pdf_from_link(link):
    # Adjust the link to point to the PDF if necessary
    link = link.replace('abs', 'pdf') + ".pdf"

    response = requests.get(link, stream=True)
    if response.status_code == 200:
        return io.BytesIO(response.content)
    else:
        print(f"Failed to download PDF from {link}")
        return None

def extract_text_from_pdf(pdf_io):
    if pdf_io:
        try:
            reader = PdfReader(pdf_io)
            text = ""
            for page in reader.pages:
                text += page.extract_text() + "\n"
            return text
        except Exception as e:
            print(f"Error occurred while extracting text from PDF: {str(e)}")
            return ""

def process_pdf_links(df):
    df['PDF_Text'] = ''
    for index, row in df.iterrows():
        # arXiv PDF links are typically the same as the abstract page link but with 'pdf' instead of 'abs'
        link = row['ID'].replace('abs', 'pdf') + ".pdf"
        print(f"Processing link: {link}")
        pdf_io = download_pdf_from_link(link)
        if pdf_io:
            text = extract_text_from_pdf(pdf_io)
            df.at[index, 'PDF_Text'] = text
        else:
            print(f"Failed to process link: {link}")
    return df

# %%
# Example usage
df = fetch_arxiv_data(search_query="quantum physics", max_results=10, start_date="2023-01-01", end_date="2023-12-31", primary_category="quant-ph", categories=["quant-ph", "cond-mat"])
df_with_pdf_text = process_pdf_links(df)
print(df_with_pdf_text)
df_with_pdf_text.to_csv('arxiv_data_with_pdf_text.csv', index=False)
# Out:
# Processing link: http://arxiv.org/pdf/quant-ph/0302169v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/quant-ph/0302169v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/quant-ph/0302169v1.pdf
# Processing link: http://arxiv.org/pdf/1212.4177v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/1212.4177v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/1212.4177v1.pdf
# Processing link: http://arxiv.org/pdf/1504.03207v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/1504.03207v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/1504.03207v1.pdf
# Processing link: http://arxiv.org/pdf/2208.08064v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/2208.08064v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/2208.08064v1.pdf
# Processing link: http://arxiv.org/pdf/cond-mat/0601285v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/cond-mat/0601285v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/cond-mat/0601285v1.pdf
# Processing link: http://arxiv.org/pdf/0811.2516v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/0811.2516v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/0811.2516v1.pdf
# Processing link: http://arxiv.org/pdf/1807.11019v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/1807.11019v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/1807.11019v1.pdf
# Processing link: http://arxiv.org/pdf/quant-ph/0201082v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/quant-ph/0201082v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/quant-ph/0201082v1.pdf
# Processing link: http://arxiv.org/pdf/quant-ph/0309066v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/quant-ph/0309066v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/quant-ph/0309066v1.pdf
# Processing link: http://arxiv.org/pdf/quant-ph/0504224v1.pdf
# Failed to download PDF from http://arxiv.org/pdf/quant-ph/0504224v1.pdf.pdf
# Failed to process link: http://arxiv.org/pdf/quant-ph/0504224v1.pdf
#                                                Title  \
# 0  Nonlinear Dynamics In Quantum Physics -- Quant...
# 1                            Quantum spherical model
# 2  Can classical physics agree with quantum physi...
# 3                 The Physics of Quantum Information
# 4  Topologization of electron liquids with Chern-...
# 5  Operational Quantum Mechanics, Quantum Axiomat...
# 6  Universal Uncertainty Principle in Different Q...
# 7  Quantum Computers and Quantum Computer Languag...
# 8  Probabilistic foundations of quantum mechanics...
# 9        From quantum graphs to quantum random walks
#
#                         Authors             Published               Updated  \
# 0                   [H. Kröger]  2003-02-21T20:20:47Z  2003-02-21T20:20:47Z
# 1                   [I. Lyberg]  2012-12-17T22:06:56Z  2012-12-17T22:06:56Z
# 2            [Michele Marrocco]  2015-04-13T15:04:26Z  2015-04-13T15:04:26Z
# 3               [John Preskill]  2022-08-17T04:35:36Z  2022-08-17T04:35:36Z
# 4               [Zhenghan Wang]  2006-01-13T09:06:10Z  2006-01-13T09:06:10Z
# 5              [Diederik Aerts]  2008-11-15T18:37:02Z  2008-11-15T18:37:02Z
# 6  [C. Huang, Yong-Chang Huang]  2018-07-29T07:50:32Z  2018-07-29T07:50:32Z
# 7               [Stephen Blaha]  2002-01-18T15:08:05Z  2002-01-18T15:08:05Z
# 8           [Andrei Khrennikov]  2003-09-08T09:37:27Z  2003-09-08T09:37:27Z
# 9               [Gregor Tanner]  2005-04-29T09:41:00Z  2005-04-29T09:41:00Z
#
#                                              Summary  \
# 0  We discuss the recently proposed quantum actio...
# 1  We define a "quantum spherical model", a quant...
# 2  Classical physics fails where quantum physics ...
# 3  Rapid ongoing progress in quantum information ...
# 4  We discuss a nexus among quantum topology, qua...
# 5  The role of operational quantum mechanics, qua...
# 6  This paper deduces universal uncertainty princ...
# 7  We show a representation of Quantum Computers ...
# 8  We discuss foundation of quantum mechanics (in...
# 9  We give a short overview over recent developme...
#
#                                         ID PDF_Text
# 0  http://arxiv.org/abs/quant-ph/0302169v1
# 1         http://arxiv.org/abs/1212.4177v1
# 2        http://arxiv.org/abs/1504.03207v1
# 3        http://arxiv.org/abs/2208.08064v1
# 4  http://arxiv.org/abs/cond-mat/0601285v1
# 5         http://arxiv.org/abs/0811.2516v1
# 6        http://arxiv.org/abs/1807.11019v1
# 7  http://arxiv.org/abs/quant-ph/0201082v1
# 8  http://arxiv.org/abs/quant-ph/0309066v1
# 9  http://arxiv.org/abs/quant-ph/0504224v1
