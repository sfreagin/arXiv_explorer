# %%
from wordcloud_generator import generate_wordcloud_from_csv

# Assuming 'example_output.csv' is in your current working directory
csv_file = 'example_output.csv'
generate_wordcloud_from_csv(csv_file)
# Out:
# Word cloud generated and saved as 'wordcloud_output.png'.

# %%
# %run wordcloud.py
