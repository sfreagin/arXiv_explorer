# %%
import pandas as pd
from arxiv_api import arxiv_query

import string

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = arxiv_query('quant-ph','20240201','20240209')

# %%
df
# Out:
#                                                  Title  \
# 0    Non-Markovian Dynamics in Fiber Delay-line Buf...
# 1    Practical No-Switching Continuous-Variable Qua...
# 2    A study of chaos and randomness in quantum sys...
# 3    Quantum Information Geometry with Non-Hermitia...
# 4    Error-Tolerant Amplification and Simulation of...
# ..                                                 ...
# 270  Designing three-way entangled and nonlocal two...
# 271                     Resources of the Quantum World
# 272                     The $φ^n$ trajectory bootstrap
# 273              Magic Class and the Convolution Group
# 274                           The fate of entanglement
#
#                                     ID             Published  \
# 0    http://arxiv.org/abs/2402.00274v1  2024-02-01T01:50:51Z
# 1    http://arxiv.org/abs/2402.00277v1  2024-02-01T02:02:56Z
# 2    http://arxiv.org/abs/2402.00287v1  2024-02-01T02:35:01Z
# 3    http://arxiv.org/abs/2402.00374v1  2024-02-01T06:28:21Z
# 4    http://arxiv.org/abs/2402.00379v1  2024-02-01T06:55:59Z
# ..                                 ...                   ...
# 270  http://arxiv.org/abs/2402.05080v2  2024-02-07T18:33:28Z
# 271  http://arxiv.org/abs/2402.05474v1  2024-02-08T08:05:02Z
# 272  http://arxiv.org/abs/2402.05778v1  2024-02-08T16:09:06Z
# 273  http://arxiv.org/abs/2402.05780v1  2024-02-08T16:12:16Z
# 274  http://arxiv.org/abs/2402.06677v1  2024-02-07T19:00:06Z
#
#                   Updated                                            Summary  \
# 0    2024-02-01T01:50:51Z    We study the non-Markovian effect on a two-p...
# 1    2024-02-01T02:02:56Z    Continuous-variable quantum key distribution...
# 2    2024-02-01T02:35:01Z    How classical chaos emerges from the underly...
# 3    2024-02-01T06:28:21Z    Information geometry is the application of d...
# 4    2024-02-01T06:55:59Z    Cat-state qubits formed by photonic cat stat...
# ..                    ...                                                ...
# 270  2024-02-08T06:02:20Z    Entanglement with single-particle states is ...
# 271  2024-02-08T08:05:02Z    This book delves into the burgeoning field o...
# 272  2024-02-08T16:09:06Z    The Green's functions $G_n=\langle\phi^n\ran...
# 273  2024-02-08T16:12:16Z    The classification of many-body quantum stat...
# 274  2024-02-07T19:00:06Z    Quantum entanglement is a fundamentally non-...
#
#                                                 Author  \
# 0                   [\nKim Fook Lee\n, \nPrem Kumar\n]
# 1    [\nJiale Mi\n, \nYiming Bian\n, \nLu Fan\n, \n...
# 2                                     [\nSreeram PG\n]
# 3    [\nWangjun Lu\n, \nZhao-Hui Peng\n, \n HongTao\n]
# 4    [\nYe-Hong Chen\n, \nZhi-Cheng Shi\n, \nFranco...
# ..                                                 ...
# 270       [\nDinesh Kumar Panda\n, \nColin Benjamin\n]
# 271                                   [\nGilad Gour\n]
# 272                                  [\nWenliang Li\n]
# 273  [\nKaifeng Bu\n, \nArthur Jaffe\n, \nZixia Wei\n]
# 274     [\nGilles Parez\n, \nWilliam Witczak-Krempa\n]
#
#                                               Comments Journal_Ref  \
# 0                                  21 pages, 4 figures
# 1                                 15 pages, 10 figures
# 2                                           PhD Thesis
# 3
# 4             7 pages, 7 figures, comments are welcome
# ..                                                 ...         ...
# 270                               13 pages, 10 figures
# 271  956 Pages (including appendices), Preliminary ...
# 272                                21 pages, 9 figures
# 273                                          6+2 pages
# 274              14+3 pages single column, 3+1 figures
#
#                                   Link Primary_Category  \
# 0    http://arxiv.org/abs/2402.00274v1         quant-ph
# 1    http://arxiv.org/abs/2402.00277v1         quant-ph
# 2    http://arxiv.org/abs/2402.00287v1         quant-ph
# 3    http://arxiv.org/abs/2402.00374v1         quant-ph
# 4    http://arxiv.org/abs/2402.00379v1         quant-ph
# ..                                 ...              ...
# 270  http://arxiv.org/abs/2402.05080v2         quant-ph
# 271  http://arxiv.org/abs/2402.05474v1         quant-ph
# 272  http://arxiv.org/abs/2402.05778v1           hep-th
# 273  http://arxiv.org/abs/2402.05780v1         quant-ph
# 274  http://arxiv.org/abs/2402.06677v1         quant-ph
#
#                                             Categories DOI License Affiliation
# 0                                           [quant-ph]                      []
# 1                                           [quant-ph]                      []
# 2                                           [quant-ph]                      []
# 3                                           [quant-ph]                      []
# 4                                           [quant-ph]                      []
# ..                                                 ...  ..     ...         ...
# 270  [quant-ph, cond-mat.dis-nn, cs.SY, eess.SY, ph...                      []
# 271       [quant-ph, cs.IT, math-ph, math.IT, math.MP]                      []
# 272  [hep-th, cond-mat.stat-mech, hep-lat, nucl-th,...                      []
# 273  [quant-ph, cond-mat.stat-mech, hep-th, math-ph...                      []
# 274  [quant-ph, cond-mat.mes-hall, cond-mat.stat-me...                      []
#
# [275 rows x 14 columns]

# %%
df['Summary']
# Out:
# 0        We study the non-Markovian effect on a two-p...
# 1        Continuous-variable quantum key distribution...
# 2        How classical chaos emerges from the underly...
# 3        Information geometry is the application of d...
# 4        Cat-state qubits formed by photonic cat stat...
#                              ...
# 270      Entanglement with single-particle states is ...
# 271      This book delves into the burgeoning field o...
# 272      The Green's functions $G_n=\langle\phi^n\ran...
# 273      The classification of many-body quantum stat...
# 274      Quantum entanglement is a fundamentally non-...
# Name: Summary, Length: 275, dtype: object

# %%
def simple_cleaner(my_string):
    #remove punctuation
    my_string = my_string.translate(str.maketrans(" "," ",string.punctuation))
    
    #lower case, split, remove stopwords
    my_string = [w for w in my_string.lower().split() if w not in stop_words]
    
    return " ".join(my_string)

# %%
df['cleaned_text'] = df['Summary'].apply(simple_cleaner)

# %%
tfidf_text = TfidfVectorizer(min_df=5, max_df=0.7)

vectors_text = tfidf_text.fit_transform(df['cleaned_text'])

# %%
vectors_text.shape
# Out:
# (275, 1092)

# %% [markdown]
# ### NMF

# %%
from sklearn.decomposition import NMF

# %%
nmf_text_model = NMF(n_components=10)

W_text_matrix = nmf_text_model.fit_transform(vectors_text)
H_text_matrix = nmf_text_model.components_

# %%
def display_topics(model, features, no_top_words=5):
    for topic, words in enumerate(model.components_):
        total = words.sum()
        largest = words.argsort()[::-1] # invert sort order
        print("\nTopic %02d" % topic)
        for i in range(0, no_top_words):
            print("  %s (%2.2f)" % (features[largest[i]], abs(words[largest[i]]*100.0/total)))

# %%
display_topics(nmf_text_model, tfidf_text.get_feature_names_out())
# Out:
# Topic 00
#   energy (2.09)
#   model (1.63)
#   wave (1.27)
#   equation (1.20)
#   harmonic (1.19)
#
# Topic 01
#   classical (1.94)
#   algorithm (1.85)
#   problem (1.65)
#   optimization (1.13)
#   algorithms (0.90)
#
# Topic 02
#   states (5.91)
#   state (3.07)
#   graph (2.72)
#   operations (1.06)
#   entangled (1.02)
#
# Topic 03
#   qubits (2.93)
#   qubit (2.51)
#   errors (2.00)
#   error (1.71)
#   superconducting (1.70)
#
# Topic 04
#   topological (6.00)
#   phase (3.00)
#   phases (2.96)
#   magnetic (1.75)
#   boundary (1.73)
#
# Topic 05
#   entanglement (8.14)
#   negativity (1.22)
#   entropy (1.19)
#   correlations (0.91)
#   measurement (0.90)
#
# Topic 06
#   optical (1.70)
#   mode (1.47)
#   coupling (1.27)
#   cavity (1.16)
#   field (1.15)
#
# Topic 07
#   key (4.09)
#   protocol (2.97)
#   rate (2.67)
#   secret (2.53)
#   protocols (2.35)
#
# Topic 08
#   systems (2.83)
#   dynamics (1.90)
#   spin (1.68)
#   control (1.03)
#   open (0.91)
#
# Topic 09
#   neural (3.25)
#   models (1.94)
#   networks (1.85)
#   model (1.73)
#   learning (1.71)

# %% [markdown]
# ### SVDf

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd_text_model = TruncatedSVD(n_components=10)

W_svd_text_matrix = svd_text_model.fit_transform(vectors_text)
H_svd_text_matrix = svd_text_model.components_

# %%
display_topics(svd_text_model, tfidf_text.get_feature_names_out())
# Out:
# Topic 00
#   states (0.75)
#   entanglement (0.70)
#   state (0.56)
#   systems (0.51)
#   model (0.45)
#
# Topic 01
#   entanglement (12.38)
#   states (5.97)
#   topological (5.27)
#   state (5.01)
#   phase (4.05)
#
# Topic 02
#   states (11.59)
#   entanglement (11.49)
#   graph (7.58)
#   state (5.31)
#   protocol (3.85)
#
# Topic 03
#   qubit (21.20)
#   qubits (19.69)
#   superconducting (16.32)
#   errors (12.02)
#   photon (11.38)
#
# Topic 04
#   topological (23.44)
#   states (12.43)
#   phases (10.90)
#   phase (9.35)
#   graph (8.66)
#
# Topic 05
#   entanglement (211.04)
#   topological (119.99)
#   phase (91.32)
#   phases (60.46)
#   lattice (49.62)
#
# Topic 06
#   neural (62.43)
#   optical (58.02)
#   networks (47.43)
#   topological (46.61)
#   mode (37.66)
#
# Topic 07
#   key (8.76)
#   protocol (7.27)
#   secret (7.05)
#   rate (6.89)
#   codes (6.59)
#
# Topic 08
#   systems (32.62)
#   spin (19.69)
#   dynamics (18.98)
#   states (16.24)
#   control (15.43)
#
# Topic 09
#   model (233.00)
#   models (212.50)
#   neural (159.13)
#   decoherence (137.76)
#   rate (137.37)

# %% [markdown]
# ### LDA

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_text_vectorizer = CountVectorizer(min_df=5, max_df=0.7)

count_text_vectors = count_text_vectorizer.fit_transform(df['cleaned_text'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda_text_model = LatentDirichletAllocation(n_components=6)

W_lda_text_matrix = lda_text_model.fit_transform(count_text_vectors)
H_lda_text_matrix = lda_text_model.components_

# %%
pd.DataFrame(W_lda_text_matrix)[0].sort_values(ascending=False)
# Out:
# 139    0.992163
# 27     0.991052
# 132    0.989614
# 159    0.988468
# 121    0.987826
#          ...
# 2      0.001538
# 58     0.001535
# 178    0.001467
# 235    0.001450
# 105    0.001411
# Name: 0, Length: 275, dtype: float64

# %%
ranked_list = pd.DataFrame(W_lda_text_matrix)[0].sort_values(ascending=False).index

# %%
pd.DataFrame(W_lda_text_matrix)[0].iloc[ranked_list].reset_index(drop=True)
# Out:
# 0      0.992163
# 1      0.991052
# 2      0.989614
# 3      0.988468
# 4      0.987826
#          ...
# 270    0.001538
# 271    0.001535
# 272    0.001467
# 273    0.001450
# 274    0.001411
# Name: 0, Length: 275, dtype: float64

# %%
[i for i in pd.DataFrame(W_lda_text_matrix)[0]]
# Out:
# [0.9828541978571613,
#  0.0018636912192771817,
#  0.0015384116547627683,
#  0.0028552439159449427,
#  0.003064400207663696,
#  0.0020429259760347714,
#  0.5533922372119962,
#  0.003167135179428334,
#  0.0016475256368910745,
#  0.0031665693256508493,
#  0.0031767128899725158,
#  0.003176928436440112,
#  0.0017341929538547676,
#  0.0021265141565457424,
#  0.0021604816224278386,
#  0.0016622955544369584,
#  0.1850965499989846,
#  0.0018676603257610734,
#  0.002432944947490659,
#  0.004193325587532155,
#  0.0022688068846920036,
#  0.003364020450865573,
#  0.0033016613721896446,
#  0.001625807085439015,
#  0.002961964783544094,
#  0.0028533895067845666,
#  0.002762730514377466,
#  0.9910517132145006,
#  0.3815398480510734,
#  0.002075597989246535,
#  0.002851796574512234,
#  0.0026541033284699493,
#  0.008353706799138862,
#  0.0021885011937196656,
#  0.002630336296492943,
#  0.004399007799340676,
#  0.0017441028939672576,
#  0.0017995642736541664,
#  0.0017150085405913896,
#  0.00275024374648161,
#  0.0018846517819152424,
#  0.0020659288789857946,
#  0.003040809618838888,
#  0.003423250225221368,
#  0.0027007348889169533,
#  0.002009580129285406,
#  0.0019173794566153337,
#  0.0019099950056842615,
#  0.0036698640411219003,
#  0.001978112398655236,
#  0.0015954253424483272,
#  0.3915191109044513,
#  0.0031674983264503827,
#  0.002837536839231686,
#  0.0017079707007030358,
#  0.004936130498521427,
#  0.3307078190132411,
#  0.002750705999961162,
#  0.0015348651500386005,
#  0.00622687457499314,
#  0.9835401918128831,
#  0.0017416394826500986,
#  0.0034282934083666285,
#  0.003647740074070605,
#  0.006234889417584143,
#  0.002291069988960074,
#  0.004948714789389902,
#  0.0019344698140263236,
#  0.0027928790894599723,
#  0.6653703249682873,
#  0.002655991232659687,
#  0.006461815387041349,
#  0.002043034680427233,
#  0.002235957423880804,
#  0.0037377435795021103,
#  0.001769757794647974,
#  0.0024301684973106934,
#  0.0017116600171540788,
#  0.004450215312977023,
#  0.005239885920151723,
#  0.002430951181399714,
#  0.002429294492503414,
#  0.004314276247936834,
#  0.003834311400104619,
#  0.0021919200401910592,
#  0.0022808336920520462,
#  0.002290697346245495,
#  0.002111525685116491,
#  0.9828774447089247,
#  0.0035757422350735056,
#  0.22396387730601858,
#  0.0024722029405918047,
#  0.001774198515789864,
#  0.0018811978276802323,
#  0.0021847900809257724,
#  0.0023620586613969517,
#  0.1581408274976852,
#  0.0016580093906500746,
#  0.003439939759991573,
#  0.004690957888992363,
#  0.003350595514731259,
#  0.002749492974768554,
#  0.39430810020052004,
#  0.002884579069112119,
#  0.0021011903274358494,
#  0.001410846994919811,
#  0.0024755585795785567,
#  0.0022664792853832284,
#  0.004296073241115508,
#  0.0025736871065938503,
#  0.00223365173929072,
#  0.0017472221745307244,
#  0.001825605967027172,
#  0.005793506045128269,
#  0.002546764971330743,
#  0.002471376128922719,
#  0.98386540554089,
#  0.002057190332319926,
#  0.001713625174996934,
#  0.0015875616748759812,
#  0.0020195940798547487,
#  0.9878257560688941,
#  0.004674931816364853,
#  0.23978459237515135,
#  0.0024311287922721206,
#  0.0037242294989669506,
#  0.986031296556979,
#  0.5049164186648797,
#  0.9820743484237695,
#  0.34942710250468306,
#  0.9790717436439641,
#  0.7198429477566028,
#  0.9896137250705067,
#  0.003651194053040419,
#  0.0023945121574871753,
#  0.003576227573942607,
#  0.002845454732397669,
#  0.00529046315331894,
#  0.005772636390161386,
#  0.9921632001395079,
#  0.0020719994101177676,
#  0.0025056809217716375,
#  0.0043157091121183,
#  0.002557283866088315,
#  0.0031836399472114675,
#  0.0027005368053684645,
#  0.15394957551492114,
#  0.0023659877675213073,
#  0.4542816543120042,
#  0.004413042225827037,
#  0.0041983397970972725,
#  0.002119424380193793,
#  0.5029206976395857,
#  0.0029026306799537997,
#  0.003432473930059198,
#  0.002095889477991616,
#  0.2057932094212851,
#  0.0027487944351513066,
#  0.0028948253433138597,
#  0.9884679554772361,
#  0.003311876234096784,
#  0.005264994323937718,
#  0.0034299882924270254,
#  0.005103204008122462,
#  0.002440415897749647,
#  0.0028439535798237808,
#  0.0027106938732025182,
#  0.2572908073401361,
#  0.00293919746573172,
#  0.002664552887245019,
#  0.005576689104213056,
#  0.002846023212868027,
#  0.0017074633690955065,
#  0.0053950718411441105,
#  0.0030067393193694736,
#  0.005100908148223966,
#  0.0049324082900156115,
#  0.9437782462812767,
#  0.0014668954298039192,
#  0.015213045041606223,
#  0.0016180900959549837,
#  0.0057945695005367235,
#  0.0029940637192560128,
#  0.27184559200076797,
#  0.00442550437587563,
#  0.0017173624200704717,
#  0.0018955780849985572,
#  0.9825362932750771,
#  0.003287421689072077,
#  0.002044506846739345,
#  0.32444353582084234,
#  0.0029347579250688766,
#  0.004930990874743197,
#  0.0042100110125058,
#  0.0049525653173038645,
#  0.0017029470284515933,
#  0.12274412676628728,
#  0.0026212772984547865,
#  0.9855376819008769,
#  0.007587963190932056,
#  0.0026386933062065346,
#  0.002756277364494879,
#  0.003829330534894048,
#  0.0016129203772523555,
#  0.059662491380681165,
#  0.0027547878735499406,
#  0.0031293617322704173,
#  0.005083730888253969,
#  0.0036690786497186804,
#  0.002186615299297116,
#  0.003840775670973195,
#  0.43382167732860194,
#  0.5224486830390258,
#  0.0025698342675414244,
#  0.005237750764654488,
#  0.9874695700262097,
#  0.003119857188909147,
#  0.005426025081278811,
#  0.0016695241859182625,
#  0.002504950046352194,
#  0.0018103229990326338,
#  0.002462220675592545,
#  0.0025172787029924524,
#  0.001960572517267026,
#  0.0025034869658591037,
#  0.002512047883131541,
#  0.005783634478856842,
#  0.002217241657666222,
#  0.0030575829921666376,
#  0.0030509546745377566,
#  0.0026199328547506467,
#  0.002959826013394124,
#  0.0026274645761245733,
#  0.0024340370441757395,
#  0.00181416517143545,
#  0.0014504668422410233,
#  0.003246010982975905,
#  0.002273628866505499,
#  0.002672825527559307,
#  0.0019212887006602936,
#  0.002027247520259165,
#  0.003108287213003744,
#  0.0018689168904896148,
#  0.0018953163206528298,
#  0.47347967267607316,
#  0.0073103674570687074,
#  0.003583930147365519,
#  0.0025465003327740142,
#  0.9778611304739285,
#  0.002335941067283289,
#  0.003230289415491342,
#  0.004085997410543782,
#  0.10246646351040976,
#  0.0026628588193689786,
#  0.002005817134107736,
#  0.46697490107274386,
#  0.0026805675154565572,
#  0.002956590435453208,
#  0.0018803968168451984,
#  0.003318986857771179,
#  0.0031140811274135783,
#  0.003096843000000332,
#  0.0027619109873271903,
#  0.0021229185042027933,
#  0.0022688543793751735,
#  0.002051914210481015,
#  0.0053069791673623,
#  0.24605059524978862,
#  0.2207970309245033,
#  0.0018668141946227223,
#  0.0035708425854190772,
#  0.0028886494295165856,
#  0.003911918846583655,
#  0.0031074215796697674,
#  0.0028703899772512587]

# %%
df.iloc[ranked_list]
# Out:
#                                                  Title  \
# 139                  The Casimir effect at the nucleus
# 27   Continuously Distributing Entanglement in Quan...
# 132  All graph state verification protocols are com...
# 159  A metronome spin stabilizes time-crystalline d...
# 121        Quantum Nonlocality: how does Nature do it?
# ..                                                 ...
# 2    A study of chaos and randomness in quantum sys...
# 58   State Dependent and Independent Uncertainty Re...
# 178  Magnetic field effects on the Kitaev model cou...
# 235  Curriculum reinforcement learning for quantum ...
# 105  Maximally entangled mixed states for a fixed s...
#
#                                     ID             Published  \
# 139  http://arxiv.org/abs/2402.01776v1  2024-02-01T14:57:24Z
# 27   http://arxiv.org/abs/2402.01527v1  2024-02-02T16:14:50Z
# 132  http://arxiv.org/abs/2402.01445v1  2024-02-02T14:37:26Z
# 159  http://arxiv.org/abs/2402.04078v1  2024-02-06T15:31:17Z
# 121  http://arxiv.org/abs/2402.00725v1  2024-02-01T16:16:10Z
# ..                                 ...                   ...
# 2    http://arxiv.org/abs/2402.00287v1  2024-02-01T02:35:01Z
# 58   http://arxiv.org/abs/2402.03159v1  2024-02-05T16:28:29Z
# 178  http://arxiv.org/abs/2402.05516v1  2024-02-08T09:51:37Z
# 235  http://arxiv.org/abs/2402.03500v1  2024-02-05T20:33:00Z
# 105  http://arxiv.org/abs/2402.05673v1  2024-02-08T13:49:34Z
#
#                   Updated                                            Summary  \
# 139  2024-02-01T14:57:24Z    In this report, the impact of the Casimir ef...
# 27   2024-02-02T16:14:50Z    Small interconnected quantum processors can ...
# 132  2024-02-02T14:37:26Z    Graph state verification protocols allow mul...
# 159  2024-02-06T15:31:17Z    We investigate a disorder-free quantum Ising...
# 121  2024-02-01T16:16:10Z    We answer the question asked by Nicolas Gisi...
# ..                    ...                                                ...
# 2    2024-02-01T02:35:01Z    How classical chaos emerges from the underly...
# 58   2024-02-05T16:28:29Z    To understand the direct impact of noncommut...
# 178  2024-02-08T09:51:37Z    Open quantum systems display unusual phenome...
# 235  2024-02-05T20:33:00Z    The key challenge in the noisy intermediate-...
# 105  2024-02-08T13:49:34Z    Entanglement is a resource under local opera...
#
#                                                 Author  \
# 139                                  [\nFrank Kowol\n]
# 27   [\nLars Talsma\n, \nÁlvaro G. Iñesta\n, \nStep...
# 132  [\nLéo Colisson\n, \nDamian Markham\n, \nRaja ...
# 159  [\nNiklas Euler\n, \nAdrian Braemer\n, \nLuca ...
# 121                            [\nMarian Kupczynski\n]
# ..                                                 ...
# 2                                     [\nSreeram PG\n]
# 58                                        [\n Sahil\n]
# 178  [\nKiyu Fukui\n, \nYasuyuki Kato\n, \nYukitosh...
# 235  [\nYash J. Patel\n, \nAkash Kundu\n, \nMateusz...
# 105                          [\nJulio I. de Vicente\n]
#
#                                               Comments Journal_Ref  \
# 139                                26 pages, 7 figures
# 27   8 pages with 4 figures (main text); 11 pages a...
# 132                                           48 pages
# 159
# 121                           19 pages, 100 references
# ..                                                 ...         ...
# 2                                           PhD Thesis
# 58                                 18 pages, no figure
# 178                               16 pages, 10 figures
# 235  32 pages, 11 figures, 6 tables. Accepted at IC...
# 105                                            5 pages
#
#                                   Link Primary_Category  \
# 139  http://arxiv.org/abs/2402.01776v1  physics.atom-ph
# 27   http://arxiv.org/abs/2402.01527v1         quant-ph
# 132  http://arxiv.org/abs/2402.01445v1         quant-ph
# 159  http://arxiv.org/abs/2402.04078v1         quant-ph
# 121  http://arxiv.org/abs/2402.00725v1         quant-ph
# ..                                 ...              ...
# 2    http://arxiv.org/abs/2402.00287v1         quant-ph
# 58   http://arxiv.org/abs/2402.03159v1         quant-ph
# 178  http://arxiv.org/abs/2402.05516v1  cond-mat.str-el
# 235  http://arxiv.org/abs/2402.03500v1         quant-ph
# 105  http://arxiv.org/abs/2402.05673v1         quant-ph
#
#                           Categories DOI License Affiliation  \
# 139      [physics.atom-ph, quant-ph]                      []
# 27                        [quant-ph]                      []
# 132  [quant-ph, cs.CR, 81P94, 94A60]                      []
# 159   [quant-ph, cond-mat.stat-mech]                      []
# 121      [quant-ph, physics.hist-ph]                      []
# ..                               ...  ..     ...         ...
# 2                         [quant-ph]                      []
# 58                        [quant-ph]                      []
# 178      [cond-mat.str-el, quant-ph]                      []
# 235         [quant-ph, cs.AI, cs.LG]                      []
# 105                       [quant-ph]                      []
#
#                                           cleaned_text
# 139  report impact casimir effect nearnuclear envir...
# 27   small interconnected quantum processors collab...
# 132  graph state verification protocols allow multi...
# 159  investigate disorderfree quantum ising chain s...
# 121  answer question asked nicolas gisin article sc...
# ..                                                 ...
# 2    classical chaos emerges underlying quantum wor...
# 58   understand direct impact noncommutativity inco...
# 178  open quantum systems display unusual phenomena...
# 235  key challenge noisy intermediatescale quantum ...
# 105  entanglement resource local operations assiste...
#
# [275 rows x 15 columns]

# %%
display_topics(lda_text_model, tfidf_text.get_feature_names_out())
# Out:
# Topic 00
#   time (1.73)
#   states (1.39)
#   entanglement (1.38)
#   state (0.96)
#   effect (0.89)
#
# Topic 01
#   classical (1.23)
#   approach (1.04)
#   model (1.03)
#   problem (0.96)
#   using (0.80)
#
# Topic 02
#   graph (1.72)
#   circuits (1.40)
#   one (1.29)
#   circuit (1.27)
#   algorithms (1.26)
#
# Topic 03
#   states (3.11)
#   entanglement (2.21)
#   state (1.43)
#   system (1.05)
#   systems (0.95)
#
# Topic 04
#   key (2.18)
#   rate (1.17)
#   detection (1.12)
#   method (1.08)
#   protocol (1.06)
#
# Topic 05
#   qubits (1.43)
#   qubit (1.15)
#   systems (1.09)
#   two (0.78)
#   state (0.78)

# %% [markdown]
# ### Visualizing LDA results

# %%
import pyLDAvis.lda_model

# %%
lda_display = pyLDAvis.lda_model.prepare(lda_text_model, count_text_vectors,
                                        count_text_vectorizer, sort_topics=False)

# %%
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2798110602837606941241610" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2798110602837606941241610_data = {"mdsDat": {"x": [-0.09752296229923835, -0.16276668811530096, 0.08760142053950187, -0.08821346928056684, 0.1537101979754858, 0.10719150118011835], "y": [0.07074595225870167, 0.020763350897953215, 0.14517535992437108, -0.13052849967162558, -0.05533182397374711, -0.0508243394356537], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [20.45425473856908, 12.869438589759605, 20.435329251331197, 18.14796112523472, 12.321479386828234, 15.77153690827717]}, "tinfo": {"Term": ["algorithm", "error", "circuit", "entanglement", "algorithms", "gates", "learning", "noise", "qubits", "optimization", "state", "states", "system", "data", "phase", "circuits", "energy", "field", "measurements", "coupling", "errors", "computing", "qubit", "computers", "code", "gate", "classical", "entangled", "dynamics", "problem", "depth", "vqe", "cutting", "combinatorial", "annealing", "synthesis", "barren", "minima", "optimisation", "grovers", "molecule", "qaoa", "epsilon", "gradient", "shallow", "diagrams", "optimization", "factorization", "vqas", "flexible", "cut", "register", "plateaus", "risk", "usage", "thesis", "native", "molecules", "hadamard", "gradients", "eigensolver", "variational", "algorithm", "solving", "circuit", "circuits", "polynomial", "hamiltonians", "ansatz", "solutions", "solution", "decomposition", "problems", "algorithms", "problem", "gates", "hamiltonian", "method", "number", "ground", "solve", "computer", "using", "approach", "optimal", "unitary", "computers", "used", "results", "state", "function", "qubits", "time", "methods", "classical", "show", "energy", "gate", "one", "based", "model", "work", "mitigation", "nisq", "benchmarks", "gatebased", "computationally", "classifier", "intermediatescale", "numerous", "program", "noiseless", "machine", "variants", "shots", "learning", "supervised", "outputs", "manner", "datasets", "learn", "demanding", "samples", "improving", "mnist", "contemporary", "estimates", "decoding", "reset", "issues", "progress", "comprehensive", "decoder", "data", "software", "development", "classification", "challenges", "noisy", "realtime", "error", "ibm", "estimation", "computers", "noise", "computing", "devices", "existing", "algorithms", "techniques", "methods", "complexity", "performance", "models", "classical", "tasks", "simulation", "hardware", "reservoir", "work", "advantage", "applications", "errors", "method", "model", "algorithm", "number", "however", "qubits", "results", "systems", "nonlocality", "inequality", "inequalities", "nonclassicality", "violation", "radiation", "bells", "locc", "criterion", "chsh", "quantumness", "witnesses", "tight", "bob", "realism", "game", "alice", "incompatibility", "paradox", "answer", "consequently", "dimensional", "letter", "party", "interpretation", "steering", "criteria", "operational", "bellchsh", "marginals", "bell", "nonlocal", "relations", "action", "tomography", "property", "rule", "wigner", "bases", "mechanics", "measures", "notion", "bipartite", "measurements", "theory", "parties", "entanglement", "relation", "states", "measurement", "pure", "mixed", "density", "local", "state", "entropy", "bound", "correlations", "information", "classical", "entangled", "operators", "one", "probability", "set", "show", "two", "also", "systems", "cannot", "given", "based", "using", "space", "general", "system", "new", "results", "model", "qkd", "gkp", "secure", "security", "fiber", "resonators", "memories", "internet", "repeaters", "rf", "attacks", "heralded", "correcting", "transmission", "modulators", "repeater", "timebin", "communications", "attack", "telecom", "code", "couplers", "propagating", "trusted", "microwave", "networking", "amplifier", "coupler", "pave", "singleshot", "leakage", "surface", "readout", "detectors", "logical", "rate", "superconducting", "optical", "nodes", "qubit", "key", "pulses", "qubits", "errors", "networks", "gate", "correction", "communication", "protocol", "codes", "scheme", "fidel ...

# %%
def display_topics(model, features, no_top_words=5):
    for topic, words in enumerate(model.components_):
        total = words.sum()
        largest = words.argsort()[::-1] # invert sort order
        print("\nTopic %02d" % topic)
        for i in range(0, no_top_words):
            print("  %s (%2.2f)" % (features[largest[i]], abs(words[largest[i]]*100.0/total)))

# %%
features = tfidf_text.get_feature_names_out()

def relevant_terms(lda_text_model, features):
    term_list = []
    for topic, words in enumerate(lda_text_model.components_):
        total = words.sum()
        largest = words.argsort()[::-1] # invert sort order
        term_list.append(", ".join([features[largest[i]] for i in range(0, 5)]))

    return term_list

# %%
[", ".join([features[largest[i]] for i in range(0, 5)])]
# Out:
# ['qubits, qubit, systems, two, state']

# %%
relevant_terms(lda_text_model, features)
# Out:
# (5,
#  ['time, states, entanglement, state, effect',
#   'classical, approach, model, problem, using',
#   'graph, circuits, one, circuit, algorithms',
#   'states, entanglement, state, system, systems',
#   'key, rate, detection, method, protocol',
#   'qubits, qubit, systems, two, state'])
